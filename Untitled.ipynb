# %%
import pandas as pd

# %%
google = pd.read_csv('data/google_stock_price.csv').squeeze()

# %%
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
mappings = {i : 10 * i for i in range(1, 11)}

# %%
mappings
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60, 7: 70, 8: 80, 9: 90, 10: 100}

# %%
mapped_google = google.map(mappings)

# %%
import numpy as np
mapped_google.values
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
np.isnan(mapped_google).values
# Out:
# array([ True,  True,  True, ...,  True,  True,  True])

# %%
count
# Out:
# 0

# %%
nba = pd.read_csv('data/nba.csv')

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba[['Name', 'Team']]
# Out:
#               Name            Team
# 0    Avery Bradley  Boston Celtics
# 1      Jae Crowder  Boston Celtics
# 2     John Holland  Boston Celtics
# 3      R.J. Hunter  Boston Celtics
# 4    Jonas Jerebko  Boston Celtics
# ..             ...             ...
# 453   Shelvin Mack       Utah Jazz
# 454      Raul Neto       Utah Jazz
# 455   Tibor Pleiss       Utah Jazz
# 456    Jeff Withey       Utah Jazz
# 457            NaN             NaN
#
# [458 rows x 2 columns]

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba['Age2'] = 23

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Age2
# 0                Texas  7730337.0    23
# ...

# %%
nba['Age squared'] = nba['Age'].apply(lambda x :  x ** 2)

# %%
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary  Age2  Age squared
# ...

# %%
nba['Age'] = 2

# %%
nba
# Out:
#               Name            Team  Number Position  Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG    2    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF    2    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG    2    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG    2    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF    2   6-10   231.0
# ..             ...             ...     ...      ...  ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG    2    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG    2    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C    2    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C    2    7-0   231.0
# 457            NaN             NaN     NaN      NaN    2    NaN     NaN
#
#                College     Salary  Age2  Age squared
# ...

# %%
dict(nba.value_counts())
# Out:
# {('Aaron Brooks',
#   'Chicago Bulls',
#   0.0,
#   'PG',
#   2,
#   '6-0',
#   161.0,
#   'Oregon',
#   2250000.0,
#   23,
#   961.0): 1,
#  ('Mike Muscala',
#   'Atlanta Hawks',
#   31.0,
#   'PF',
#   2,
#   '6-11',
#   240.0,
#   'Bucknell',
#   947276.0,
#   23,
#   576.0): 1,
#  ('Mike Dunleavy',
#   'Chicago Bulls',
#   34.0,
#   'SG',
#   2,
#   '6-9',
#   230.0,
#   'Duke',
#   4500000.0,
#   23,
#   1225.0): 1,
#  ('Mike Conley',
#   'Memphis Grizzlies',
#   11.0,
#   'PG',
#   2,
#   '6-1',
#   175.0,
#   'Ohio State',
#   9588426.0,
#   23,
#   784.0): 1,
#  ('Michael Kidd-Gilchrist',
#   'Charlotte Hornets',
#   14.0,
#   'SF',
#   2,
#   '6-7',
#   232.0,
#   'Kentucky',
#   6331404.0,
#   23,
#   484.0): 1,
#  ('Michael Carter-Williams',
#   'Milwaukee Bucks',
#   5.0,
#   'PG',
#   2,
#   '6-6',
#   190.0,
#   'Syracuse',
#   2399040.0,
#   23,
#   576.0): 1,
#  ('Michael Beasley',
#   'Houston Rockets',
#   8.0,
#   'SF',
#   2,
#   '6-10',
#   235.0,
# ...

# %%
nba.Position.value_counts(normalize=True) * 100
# Out:
# SG    22.319475
# PF    21.881838
# PG    20.131291
# SF    18.599562
# C     17.067834
# Name: Position, dtype: float64
